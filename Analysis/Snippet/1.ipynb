# %%
import torch

# Check PyTorch's internal CUDA state
import torch
print(f"\nPyTorch CUDA compiled version: {torch.version.cuda}")
print(f"PyTorch version: {torch.__version__}")

# Try to get more detailed error information
try:
    torch.cuda.device_count()
except Exception as e:
    print(f"Device count error: {e}")

try:
    torch.cuda.is_available()
except Exception as e:
    print(f"Is available error: {e}")
# Out:
# Environment variables:
# CUDA_VISIBLE_DEVICES: Not set
# CUDA_DEVICE_ORDER: Not set
# __NV_PRIME_RENDER_OFFLOAD: Not set
# __GLX_VENDOR_LIBRARY_NAME: Not set
#
# PyTorch CUDA compiled version: 12.4
# PyTorch version: 2.6.0+cu124

# %%
import torch
print(torch.__version__, torch.version.cuda)
try:
    torch.cuda.init()
    print("INIT OK on:", torch.cuda.get_device_name(0))
except Exception as e:
    print("INIT FAILED:", e)
# Out:
# 2.6.0+cu124 12.4
# INIT OK on: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
import pandas as pd
df = pd.read_csv("traffic.csv")

df.shape
# Out:
# (17544, 863)
